# %%
# Required Libraries
import numpy as np
import pandas as pd
import os
import glob as gb
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from keras.models import Sequential
from keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import plotly.express as px

# Define image dimensions and batch size
image_height = 224
image_width = 224  # Fixed typo from 'image_weight'
batch_size = 32

# Specify the path to your dataset
tpath = 'aug'  # Update this with your local path if needed

# Load the training and validation data using image_dataset_from_directory
training_data = tf.keras.utils.image_dataset_from_directory(
    tpath,
    batch_size=batch_size,
    image_size=(image_height, image_width),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='training'
)

validation_data = tf.keras.utils.image_dataset_from_directory(
    tpath,
    batch_size=8,  # As in the provided code
    image_size=(image_height, image_width),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='validation'
)

# Load the metadata information (Update the path if needed)
info_file = 'labels_aug.csv'  # Update the path
info = pd.read_csv(info_file)
info.head()

# Check the column names
print(info.columns)

# Corrected pie chart to use 'label' column (assuming it's lowercase based on your code)
fig = px.pie(
    names=info['label'].unique(),
    values=info['label'].value_counts(),
    hole=0.2,
    width=500,
    height=500
)
fig.update_layout({'title': {'text': 'Class Distribution', 'x': 0.45}})
fig.show()

# Visualize class distribution in a bar plot
class_names = []
class_count = []
train_examples = 0

for f in os.listdir(tpath):
    files = gb.glob(pathname=str(tpath + "//" + f + "/*"))
    class_names.append(f)
    class_count.append(len(files))
    train_examples += len(files)

plt.figure(figsize=(30, 5))
sns.barplot(x=class_names, y=class_count)
plt.title("Class Distribution in Training Data")
plt.show()

# Optional: If you have an existing .h5 model and just want to convert to .keras without retraining
# Uncomment and run this section if applicable
# existing_model_path = 'resnet50.h5'  # Path to your pretrained .h5 file
# model = keras.models.load_model(existing_model_path)
# model.save('resnet50_converted.keras')  # Save in .keras format
# print("Model converted and saved as .keras")

# Build the ResNet50 model with transfer learning (main training section)
resnet_model = Sequential()

# Load the pre-trained ResNet50 model without the top layers
pretrained_model = keras.applications.ResNet50(
    include_top=False,
    input_shape=(image_height, image_width, 3),
    pooling=None,
    weights='imagenet'
)

# Freeze the ResNet50 layers
for layer in pretrained_model.layers:
    layer.trainable = False

resnet_model.add(pretrained_model)
resnet_model.add(GlobalAveragePooling2D())
resnet_model.add(Dropout(0.5))
resnet_model.add(Dense(512, activation='relu'))
resnet_model.add(Dense(2, activation='softmax'))  # Assuming 2 classes

resnet_model.summary()

# Compile the model
resnet_model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=SGD(learning_rate=0.0009),
    metrics=['accuracy']
)

# Train the model
epochs = 50
history_resnet = resnet_model.fit(
    training_data,
    validation_data=validation_data,
    epochs=epochs,
    verbose=1
)

# Save the trained model in .keras format
resnet_model.save('resnet50.keras')
print("Model trained and saved as resnet50.keras")
# Out:
# 2026-02-05 19:26:27.875884: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 19:26:27.973987: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 1650 files belonging to 2 classes.
# Using 1320 files for training.
# Found 1650 files belonging to 2 classes.
# Using 330 files for validation.
# Index(['filepath', 'label'], dtype='object')
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │         1,026 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,637,826 (93.99 MB)
#  Trainable params: 1,050,114 (4.01 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.6379 - loss: 0.7105 - val_accuracy: 0.8242 - val_loss: 0.4045
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.7902 - loss: 0.4760 - val_accuracy: 0.8879 - val_loss: 0.3024
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.8394 - loss: 0.3952 - val_accuracy: 0.8970 - val_loss: 0.2610
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.8477 - loss: 0.3497 - val_accuracy: 0.9061 - val_loss: 0.2321
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.8667 - loss: 0.3111 - val_accuracy: 0.9091 - val_loss: 0.2136
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.8765 - loss: 0.3037 - val_accuracy: 0.9182 - val_loss: 0.2090
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.8864 - loss: 0.2737 - val_accuracy: 0.9273 - val_loss: 0.1907
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.8947 - loss: 0.2636 - val_accuracy: 0.9303 - val_loss: 0.1846
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9061 - loss: 0.2315 - val_accuracy: 0.9333 - val_loss: 0.1756
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9083 - loss: 0.2264 - val_accuracy: 0.9333 - val_loss: 0.1718
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9053 - loss: 0.2211 - val_accuracy: 0.9303 - val_loss: 0.1762
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9129 - loss: 0.2273 - val_accuracy: 0.9424 - val_loss: 0.1642
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9152 - loss: 0.2025 - val_accuracy: 0.9485 - val_loss: 0.1603
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9182 - loss: 0.2059 - val_accuracy: 0.9515 - val_loss: 0.1580
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9235 - loss: 0.2071 - val_accuracy: 0.9576 - val_loss: 0.1515
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9098 - loss: 0.2037 - val_accuracy: 0.9545 - val_loss: 0.1504
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.9273 - loss: 0.1872 - val_accuracy: 0.9606 - val_loss: 0.1453
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9273 - loss: 0.1891 - val_accuracy: 0.9606 - val_loss: 0.1425
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.9311 - loss: 0.1821 - val_accuracy: 0.9576 - val_loss: 0.1442
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.9265 - loss: 0.1843 - val_accuracy: 0.9606 - val_loss: 0.1406
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.9311 - loss: 0.1834 - val_accuracy: 0.9636 - val_loss: 0.1352
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.9386 - loss: 0.1673 - val_accuracy: 0.9636 - val_loss: 0.1346
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9341 - loss: 0.1741 - val_accuracy: 0.9636 - val_loss: 0.1307
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9341 - loss: 0.1726 - val_accuracy: 0.9606 - val_loss: 0.1283
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9455 - loss: 0.1534 - val_accuracy: 0.9606 - val_loss: 0.1278
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9417 - loss: 0.1677 - val_accuracy: 0.9606 - val_loss: 0.1254
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9439 - loss: 0.1662 - val_accuracy: 0.9667 - val_loss: 0.1273
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9341 - loss: 0.1656 - val_accuracy: 0.9636 - val_loss: 0.1278
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9462 - loss: 0.1443 - val_accuracy: 0.9697 - val_loss: 0.1242
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9492 - loss: 0.1546 - val_accuracy: 0.9697 - val_loss: 0.1225
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9371 - loss: 0.1596 - val_accuracy: 0.9697 - val_loss: 0.1229
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9394 - loss: 0.1549 - val_accuracy: 0.9636 - val_loss: 0.1258
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9439 - loss: 0.1464 - val_accuracy: 0.9697 - val_loss: 0.1218
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9409 - loss: 0.1522 - val_accuracy: 0.9727 - val_loss: 0.1171
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9508 - loss: 0.1453 - val_accuracy: 0.9727 - val_loss: 0.1168
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9523 - loss: 0.1409 - val_accuracy: 0.9697 - val_loss: 0.1147
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.9538 - loss: 0.1269 - val_accuracy: 0.9727 - val_loss: 0.1135
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.9538 - loss: 0.1466 - val_accuracy: 0.9697 - val_loss: 0.1127
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.9561 - loss: 0.1445 - val_accuracy: 0.9697 - val_loss: 0.1143
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9538 - loss: 0.1287 - val_accuracy: 0.9697 - val_loss: 0.1145
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9432 - loss: 0.1340 - val_accuracy: 0.9697 - val_loss: 0.1078
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9439 - loss: 0.1346 - val_accuracy: 0.9697 - val_loss: 0.1089
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9530 - loss: 0.1343 - val_accuracy: 0.9697 - val_loss: 0.1109
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9477 - loss: 0.1287 - val_accuracy: 0.9667 - val_loss: 0.1187
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9447 - loss: 0.1478 - val_accuracy: 0.9697 - val_loss: 0.1089
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9523 - loss: 0.1188 - val_accuracy: 0.9697 - val_loss: 0.1055
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9530 - loss: 0.1291 - val_accuracy: 0.9697 - val_loss: 0.1050
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - accuracy: 0.9568 - loss: 0.1335 - val_accuracy: 0.9667 - val_loss: 0.1069
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.9538 - loss: 0.1191 - val_accuracy: 0.9697 - val_loss: 0.1030
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.9606 - loss: 0.1208 - val_accuracy: 0.9667 - val_loss: 0.1053
# Model trained and saved as resnet50.keras

# %%
# Visualize training and validation accuracy
import matplotlib.pyplot as plt

plt.plot(history_resnet.history['accuracy'], label='Training Accuracy')
plt.plot(history_resnet.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# Visualize training and validation loss
plt.plot(history_resnet.history['loss'], label='Training Loss')
plt.plot(history_resnet.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
